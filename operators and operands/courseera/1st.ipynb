# %%
friends = ['Taylor', 'Alex', 'Pat', 'Eli']
for friend in friends:
    print("Hi " + friend)
# Out:
# Hi Taylor
# Hi Alex
# Hi Pat
# Hi Eli

# %%
name = "brook"
print("hello " + name)
# Out:
# hello brook

# %%
name = "alex"
print("hello "+ name)
# Out:
# hello alex

# %%
for i in range (5):
 print ("sachin")
# Out:
# sachin
# sachin
# sachin
# sachin
# sachin

# %%
print (((2050/5)-32)/9)
# Out:
# 42.0

# %%
print(2**10)
# Out:
# 1024

# %%
print(2*10)
# Out:
# 20

# %%
print(type("a"))
print(type(2))
print(type(2.5))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
