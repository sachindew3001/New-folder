# %%
def greeting(name):
 print("Welcome, " + name)
    
greeting("Kay")
greeting("Cameron")
# Out:
# Welcome, Kay
# Welcome, Cameron

# %%
def greeting(name,department):
    print("welcome, "+ name ,  )
    print("you are part of " + department)
greeting("blake","software engineering")    
greeting("sachin ","software engineering")
# Out:
# welcome, blake
# you are part of software engineering
# welcome, sachin
# you are part of software engineering

# %%
time_list =[2,22,33,12,23,7,8,9,12,33,66,]
print(sorted(time_list))
# Out:
# [2, 7, 8, 9, 12, 12, 22, 23, 33, 33, 66]

# %%
time_list= [222,89,66,43,22,111,4,5,766,]
print(max(time_list))
print(min(time_list))
# Out:
# 766
# 4

# %%
def area_traingle(base,height):
    return base*height/2
area_of_traingle_a =area_traingle (5,7)
area_of_traingle_b = area_traingle(6,8)
sum  = area_of_traingle_a + area_of_traingle_b

print("sum of area of traingle a and b: "+ str(sum))
# Out:
# sum of area of traingle a and b: 41.5

# %%
def convert_seconds(seconds):
  hours = seconds//3600
  minutes = (seconds - hours * 3600)//60

  remaining_seconds = seconds - hours * 3600 - minutes* 60
  return f"{hours}hours, {minutes}minutes,{remaining_seconds}seconds"
result = convert_seconds(5000)
print(result)
# Out:
# 1hours, 23minutes,20seconds

# %%
import time

def countdown(seconds):
    while seconds:
        hours = seconds // 3600
        minutes = (seconds % 3600) // 60
        remaining_seconds = seconds % 60
        print(f"{hours} hour {minutes} minutes {remaining_seconds} seconds", end="\r")
        time.sleep(1)
        seconds -= 1

    print("Time's up!                 ")

# Example: Countdown from 5000 seconds
countdown(5)
# Out:
# Time's up!
