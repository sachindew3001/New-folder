# %% [markdown]
# arthematic operrators
# + addition
# - subtraction
# * multiplication
# /  division
# (//) floor division
# (**) exponentation

# %%
print(9%2)
# Out:
# 1

# %% [markdown]
# here floor division(//) means quotient before decimal value
# \ (**) means 2 to the power 8 = 2((8))

# %%
print(8+2)
print(8-2)
print(8*2)
print(8%2)
print(2**8)
print(8//2)
# Out:
# 10
# 6
# 16
# 0
# 256
# 4

# %% [markdown]
# 2)  comparison operators
# 2.1|  '<' lessthan
# 2.2 '>' greater than
# 2.3)'<=' less than or equal to
# 2.4)'>=' greater than or equal to
# 2.5)'!=' not equal to

# %%
print(3>2)
print(3<2)
print(5==5)
print(5!=5)
print(5!=10)
# Out:
# True
# False
# True
# False
# True

# %%
print(3>=3)
print(3>=4)
# Out:
# True
# False

# %% [markdown]
# 3) logical operators
#  and = both the operand are ture
#  or = if one of the operand true
#  not = it gives opposite answers only

# %%
print(3>2 and 2>1)
print(3>2 or 4>2)
print(3>2 or 4>8) # shwing true because on operand is true.
print(not(3>2 or 3>4))
print(not(3>2 and 3>2))# its work is to give opposite answers only
# Out:
# True
# True
# True
# False
# False

# %% [markdown]
# 4) assignment operators
# x=6  ~ 6
# x+=6 ~ x = x+6
# x-=6 ~ x= x-6

# %%
ab = 13
ab+=5
ab-=10
print(ab)
# Out:
# 8

# %% [markdown]
# 5) identity operators
# is
# is not

# %%
a = 1234
b = "1234"

print (a is b)
# Out:
# False

# %%
a = "12345"
b = "12345"
print( a is b )
c= 1234
d= 1234

print(c is d )
# Out:
# True
# False
